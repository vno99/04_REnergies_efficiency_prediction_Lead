# %%
from pathlib import Path
from zipfile import ZipFile
from tqdm import tqdm
import pandas as pd
import boto3
from dotenv import load_dotenv
import os
import io

# %%
# Chargement API KEYS
load_dotenv()

API_KEY_S3 = os.environ["AWS_ACCESS_KEY_ID"]
API_SECRET_KEY_S3 = os.environ["AWS_SECRET_ACCESS_KEY"]

bucket_name = "renergies99-lead-bucket"
s3_prefix = "public"

# %%
# Session Boto3
session = boto3.Session(
    aws_access_key_id=API_KEY_S3,
    aws_secret_access_key=API_SECRET_KEY_S3,
    region_name="eu-west-3",
)

s3 = session.resource("s3")
bucket = s3.Bucket(bucket_name)

# Dossier S3 avec données
national_prefix = f"{s3_prefix}/raw/rte/"

# Lister les objets S3 sous ce préfixe
xlsx_keys = sorted(
    obj.key
    for obj in bucket.objects.filter(Prefix=national_prefix)
    if obj.key.endswith(".xlsx")
)

print(f"{len(xlsx_keys)} fichiers trouvés sur S3")

# 2. Charger et concaténer
dfs = []
for key in xlsx_keys:
    s3_obj = s3.Object(bucket_name, key).get()
    buffer = io.BytesIO(s3_obj["Body"].read())

    df = pd.read_excel(buffer)  # ici seulement xlsx → pas besoin de gérer xls
    dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

print(df_all.shape)
df_all.head()
# Out:
# 15 fichiers trouvés sur S3
# (503727, 40)
#   Périmètre               Nature       Date    Heures  Consommation  \
# 0    France  Données définitives 2012-01-01  00:00:00       58315.0
# 1    France  Données définitives 2012-01-01  00:15:00           NaN
# 2    France  Données définitives 2012-01-01  00:30:00       58315.0
# 3    France  Données définitives 2012-01-01  00:45:00           NaN
# 4    France  Données définitives 2012-01-01  01:00:00       56231.0
#
#    Prévision J-1  Prévision J  Fioul  Charbon     Gaz  ...  \
# 0        58200.0      58200.0  492.0     25.0  3816.0  ...
# 1        57700.0      57550.0    NaN      NaN     NaN  ...
# 2        57200.0      56900.0  492.0     25.0  3816.0  ...
# 3        56200.0      56000.0    NaN      NaN     NaN  ...
# 4        55200.0      55100.0  492.0     25.0  3834.0  ...
#
#    Hydraulique - Fil de l?eau + éclusée  Hydraulique - Lacs  \
# 0                                    ND                  ND
# 1                                   NaN                 NaN
# 2                                    ND                  ND
# 3                                   NaN                 NaN
# 4                                    ND                  ND
#
#    Hydraulique - STEP turbinage  Bioénergies - Déchets  \
# 0                            ND                     ND
# 1                           NaN                    NaN
# 2                            ND                     ND
# 3                           NaN                    NaN
# 4                            ND                     ND
#
#    Bioénergies - Biomasse  Bioénergies - Biogaz   Stockage batterie  \
# 0                      ND                    ND                 NaN
# 1                     NaN                   NaN                 NaN
# 2                      ND                    ND                 NaN
# 3                     NaN                   NaN                 NaN
# 4                      ND                    ND                 NaN
#
#    Déstockage batterie Eolien terrestre Eolien offshore
# 0                  NaN              NaN             NaN
# 1                  NaN              NaN             NaN
# 2                  NaN              NaN             NaN
# 3                  NaN              NaN             NaN
# 4                  NaN              NaN             NaN
#
# [5 rows x 40 columns]

# %%
df_all = df_all[~df_all["Heures"].astype(str).str.endswith(("15:00", "45:00"))]

# %%
# Colonnes à convertir en float (exclusions)
cols_float = [
    c for c in df_all.columns
    if c not in ["Périmètre","Nature","Date", "Heures"]
]

# Conversion en float (les valeurs invalides deviennent NaN)
df_all[cols_float] = df_all[cols_float].apply(
    lambda col: pd.to_numeric(col, errors="coerce")
)

# %%
df_all["Date"] = pd.to_datetime(
    df_all["Date"],
    format="mixed"
).dt.strftime("%Y-%m-%d")

df_all["Heures"] = pd.to_datetime(
    df_all["Heures"].astype(str)
).dt.strftime("%H:%M")
# Out:
# C:\Users\nouan\AppData\Local\Temp\ipykernel_60100\3189963899.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all["Heures"] = pd.to_datetime(

# %%
df_all.head(1000)
# Out:
#       Périmètre               Nature        Date Heures  Consommation  \
# 0        France  Données définitives  2012-01-01  00:00       58315.0
# 2        France  Données définitives  2012-01-01  00:30       58315.0
# 4        France  Données définitives  2012-01-01  01:00       56231.0
# 6        France  Données définitives  2012-01-01  01:30       56075.0
# 8        France  Données définitives  2012-01-01  02:00       55532.0
# ...         ...                  ...         ...    ...           ...
# 19990    France  Données définitives  2012-07-27  05:30       39543.0
# 19992    France  Données définitives  2012-07-27  06:00       40389.0
# 19994    France  Données définitives  2012-07-27  06:30       41363.0
# 19996    France  Données définitives  2012-07-27  07:00       42844.0
# 19998    France  Données définitives  2012-07-27  07:30       44945.0
#
#        Prévision J-1  Prévision J  Fioul  Charbon     Gaz  ...  \
# 0            58200.0      58200.0  492.0     25.0  3816.0  ...
# 2            57200.0      56900.0  492.0     25.0  3816.0  ...
# 4            55200.0      55100.0  492.0     25.0  3834.0  ...
# 6            56000.0      55400.0  491.0     25.0  3832.0  ...
# 8            56000.0      55000.0  492.0     25.0  3839.0  ...
# ...              ...          ...    ...      ...     ...  ...
# 19990        40300.0      39800.0  285.0   2115.0   659.0  ...
# 19992        41300.0      40600.0  285.0   2246.0   688.0  ...
# 19994        41900.0      41500.0  285.0   2348.0   785.0  ...
# 19996        43700.0      43200.0  286.0   2627.0   925.0  ...
# 19998        45500.0      45300.0  287.0   3000.0  1223.0  ...
#
#        Hydraulique - Fil de l?eau + éclusée  Hydraulique - Lacs  \
# 0                                       NaN                 NaN
# 2                                       NaN                 NaN
# 4                                       NaN                 NaN
# 6                                       NaN                 NaN
# 8                                       NaN                 NaN
# ...                                     ...                 ...
# 19990                                   NaN                 NaN
# 19992                                   NaN                 NaN
# 19994                                   NaN                 NaN
# 19996                                   NaN                 NaN
# 19998                                   NaN                 NaN
#
#        Hydraulique - STEP turbinage  Bioénergies - Déchets  \
# 0                               NaN                    NaN
# 2                               NaN                    NaN
# 4                               NaN                    NaN
# 6                               NaN                    NaN
# 8                               NaN                    NaN
# ...                             ...                    ...
# 19990                           NaN                    NaN
# 19992                           NaN                    NaN
# 19994                           NaN                    NaN
# 19996                           NaN                    NaN
# 19998                           NaN                    NaN
#
#        Bioénergies - Biomasse  Bioénergies - Biogaz   Stockage batterie  \
# 0                         NaN                   NaN                 NaN
# 2                         NaN                   NaN                 NaN
# 4                         NaN                   NaN                 NaN
# 6                         NaN                   NaN                 NaN
# 8                         NaN                   NaN                 NaN
# ...                       ...                   ...                 ...
# 19990                     NaN                   NaN                 NaN
# 19992                     NaN                   NaN                 NaN
# 19994                     NaN                   NaN                 NaN
# 19996                     NaN                   NaN                 NaN
# 19998                     NaN                   NaN                 NaN
#
#        Déstockage batterie  Eolien terrestre  Eolien offshore
# 0                      NaN               NaN              NaN
# 2                      NaN               NaN              NaN
# 4                      NaN               NaN              NaN
# 6                      NaN               NaN              NaN
# 8                      NaN               NaN              NaN
# ...                    ...               ...              ...
# 19990                  NaN               NaN              NaN
# 19992                  NaN               NaN              NaN
# 19994                  NaN               NaN              NaN
# 19996                  NaN               NaN              NaN
# 19998                  NaN               NaN              NaN
#
# [10000 rows x 40 columns]

# %%
# Convertir le DataFrame en CSV et résidant en mémoire
csv_buffer = io.StringIO()
df_all.to_csv(csv_buffer, index=False, encoding="utf-8")

# Upload direct sur S3
s3_key = "public/prod/eCO2mix_RTE_Annuel-Definitif.csv"

s3.Object(bucket_name, s3_key).put(Body=csv_buffer.getvalue())

print(f"CSV envoyé sur s3://{bucket_name}/{s3_key}")
# Out:
# CSV envoyé sur s3://renergies99-lead-bucket/public/prod/eCO2mix_RTE_Annuel-Definitif.csv

# %%
df_all.shape
# Out:
# (243374, 40)

# %%
df_all.head()
# Out:
#   Périmètre               Nature       Date    Heures  Consommation  \
# 0    France  Données définitives 2012-01-01  00:00:00       58315.0
# 2    France  Données définitives 2012-01-01  00:30:00       58315.0
# 4    France  Données définitives 2012-01-01  01:00:00       56231.0
# 6    France  Données définitives 2012-01-01  01:30:00       56075.0
# 8    France  Données définitives 2012-01-01  02:00:00       55532.0
#
#    Prévision J-1  Prévision J  Fioul  Charbon     Gaz  ...  \
# 0        58200.0      58200.0  492.0     25.0  3816.0  ...
# 2        57200.0      56900.0  492.0     25.0  3816.0  ...
# 4        55200.0      55100.0  492.0     25.0  3834.0  ...
# 6        56000.0      55400.0  491.0     25.0  3832.0  ...
# 8        56000.0      55000.0  492.0     25.0  3839.0  ...
#
#    Hydraulique - Fil de l?eau + éclusée  Hydraulique - Lacs  \
# 0                                   NaN                 NaN
# 2                                   NaN                 NaN
# 4                                   NaN                 NaN
# 6                                   NaN                 NaN
# 8                                   NaN                 NaN
#
#    Hydraulique - STEP turbinage  Bioénergies - Déchets  \
# 0                           NaN                    NaN
# 2                           NaN                    NaN
# 4                           NaN                    NaN
# 6                           NaN                    NaN
# 8                           NaN                    NaN
#
#    Bioénergies - Biomasse  Bioénergies - Biogaz   Stockage batterie  \
# 0                     NaN                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 4                     NaN                   NaN                 NaN
# 6                     NaN                   NaN                 NaN
# 8                     NaN                   NaN                 NaN
#
#    Déstockage batterie  Eolien terrestre  Eolien offshore
# 0                  NaN               NaN              NaN
# 2                  NaN               NaN              NaN
# 4                  NaN               NaN              NaN
# 6                  NaN               NaN              NaN
# 8                  NaN               NaN              NaN
#
# [5 rows x 40 columns]

# %%
print(df_all.info())
print(df_all.describe())
print(df_all.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243374 entries, 0 to 486733
# Data columns (total 40 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Périmètre                             243374 non-null  object
#  1   Nature                                243360 non-null  object
#  2   Date                                  243360 non-null  datetime64[ns]
#  3   Heures                                243360 non-null  object
#  4   Consommation                          243333 non-null  float64
#  5   Prévision J-1                         243360 non-null  float64
#  6   Prévision J                           243360 non-null  float64
#  7   Fioul                                 243330 non-null  float64
#  8   Charbon                               243330 non-null  float64
#  9   Gaz                                   243330 non-null  float64
#  10  Nucléaire                             243330 non-null  float64
#  11  Eolien                                243330 non-null  float64
#  12  Solaire                               243330 non-null  float64
#  13  Hydraulique                           243330 non-null  float64
#  14  Pompage                               243330 non-null  float64
#  15  Bioénergies                           243330 non-null  float64
#  16  Ech. physiques                        243330 non-null  float64
#  17  Taux de Co2                           243330 non-null  float64
#  18  Ech. comm. Angleterre                 242728 non-null  float64
#  19  Ech. comm. Espagne                    243352 non-null  float64
#  20  Ech. comm. Italie                     243342 non-null  float64
#  21  Ech. comm. Suisse                     243352 non-null  float64
#  22  Ech. comm. Allemagne-Belgique         243304 non-null  float64
#  23  Fioul - TAC                           225761 non-null  float64
#  24  Fioul - Cogén.                        225761 non-null  float64
#  25  Fioul - Autres                        225761 non-null  float64
#  26  Gaz - TAC                             225761 non-null  float64
#  27  Gaz - Cogén.                          225761 non-null  float64
#  28  Gaz - CCG                             225761 non-null  float64
#  29  Gaz - Autres                          225761 non-null  float64
#  30  Hydraulique - Fil de l?eau + éclusée  225761 non-null  float64
#  31  Hydraulique - Lacs                    225761 non-null  float64
#  32  Hydraulique - STEP turbinage          225761 non-null  float64
#  33  Bioénergies - Déchets                 225761 non-null  float64
#  34  Bioénergies - Biomasse                225761 non-null  float64
#  35  Bioénergies - Biogaz                  225761 non-null  float64
#  36   Stockage batterie                    85505 non-null   float64
#  37  Déstockage batterie                   85505 non-null   float64
#  38  Eolien terrestre                      85505 non-null   float64
#  39  Eolien offshore                       85505 non-null   float64
# dtypes: datetime64[ns](1), float64(36), object(3)
# memory usage: 76.1+ MB
# None
#                                 Date   Consommation  Prévision J-1  \
# count                         243360  243333.000000  243360.000000
# mean   2018-12-09 12:00:00.000000256   52842.921326   52458.559689
# min              2012-01-01 00:00:00   29004.000000   27500.000000
# 25%              2015-06-21 00:00:00   43932.000000   43600.000000
# 50%              2018-12-09 12:00:00   51031.000000   50600.000000
# 75%              2022-05-30 00:00:00   60624.000000   60200.000000
# max              2025-11-17 00:00:00  102098.000000  101000.000000
# std                              NaN   11777.879399   11762.361910
#
#          Prévision J          Fioul        Charbon            Gaz  \
# count  243360.000000  243330.000000  243330.000000  243330.000000
# mean    52388.128217     238.930444     727.366412    3238.702433
# min         0.000000       0.000000       0.000000     234.000000
# 25%     43600.000000      85.000000      13.000000     914.000000
# 50%     50600.000000     136.000000      60.000000    2741.000000
# 75%     60000.000000     317.000000    1119.000000    4828.000000
# max    102700.000000    5926.000000    6265.000000   10591.000000
# std     11729.765374     266.802648    1054.230237    2466.711876
#
#            Nucléaire         Eolien        Solaire  ...  \
# count  243330.000000  243330.000000  243330.000000  ...
# mean    42300.981301    3530.574717    1494.935922  ...
# min     19164.000000       0.000000       0.000000  ...
# 25%     37746.000000    1313.000000       0.000000  ...
# 50%     41873.000000    2487.000000      30.000000  ...
# 75%     47088.000000    4706.000000    2043.000000  ...
# max     61712.000000   19747.000000   19530.000000  ...
# std      7702.082871    3155.513093    2591.977141  ...
#
#        Hydraulique - Fil de l?eau + éclusée  Hydraulique - Lacs  \
# count                         225761.000000       225761.000000
# mean                            4614.380978         1808.961933
# min                             1211.000000           46.000000
# 25%                             3334.000000          962.000000
# 50%                             4720.000000         1598.000000
# 75%                             5848.000000         2422.000000
# max                             8378.000000         7211.000000
# std                             1528.944204         1116.678503
#
#        Hydraulique - STEP turbinage  Bioénergies - Déchets  \
# count                 225761.000000          225761.000000
# mean                     683.634906             477.569771
# min                        0.000000              65.000000
# 25%                       55.000000             437.000000
# 50%                      390.000000             486.000000
# 75%                     1087.000000             527.000000
# max                     4864.000000            2655.000000
# std                      775.166737              68.327198
#
#        Bioénergies - Biomasse  Bioénergies - Biogaz   Stockage batterie  \
# count           225761.000000         225761.000000        85505.000000
# mean               287.393239            274.354902           -2.232712
# min                 57.000000              0.000000         -126.000000
# 25%                236.000000            218.000000            0.000000
# 50%                290.000000            295.000000            0.000000
# 75%                339.000000            332.000000            0.000000
# max                661.000000            448.000000           92.000000
# std                 78.230395             63.500172            7.672021
#
#        Déstockage batterie  Eolien terrestre  Eolien offshore
# count         85505.000000       85505.00000     85505.000000
# mean              1.003766        3883.21042       258.083796
# min               0.000000           0.00000         0.000000
# 25%               0.000000         885.00000         0.000000
# 50%               0.000000        2747.00000        95.000000
# 75%               0.000000        5784.00000       393.000000
# max             112.000000       18470.00000      1829.000000
# std               5.144500        3914.01817       357.778723
#
# [8 rows x 37 columns]
# (243374, 40)
