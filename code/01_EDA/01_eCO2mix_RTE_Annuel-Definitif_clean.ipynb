# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %% [markdown]
# # Import dataset

# %%
# Chargement API KEYS
load_dotenv()

API_KEY_S3 = os.environ["AWS_ACCESS_KEY_ID"]
API_SECRET_KEY_S3 = os.environ["AWS_SECRET_ACCESS_KEY"]

bucket_name = "renergies99-lead-bucket"
s3_prefix = "public"

# %%
df = pd.read_csv(
    "s3://renergies99-lead-bucket/public/prod/eCO2mix_RTE_Annuel-Definitif.csv",
    index_col=0,
    storage_options={
        "key": API_KEY_S3,
        "secret": API_SECRET_KEY_S3,
    }
)

# %%
df.head()
# Out:
#                         Nature        Date Heures  Consommation  \
# Périmètre
# France     Données définitives  2012-01-01  00:00       58315.0
# France     Données définitives  2012-01-01  00:30       58315.0
# France     Données définitives  2012-01-01  01:00       56231.0
# France     Données définitives  2012-01-01  01:30       56075.0
# France     Données définitives  2012-01-01  02:00       55532.0
#
#            Prévision J-1  Prévision J  Fioul  Charbon     Gaz  Nucléaire  ...  \
# Périmètre                                                                 ...
# France           58200.0      58200.0  492.0     25.0  3816.0    52697.0  ...
# France           57200.0      56900.0  492.0     25.0  3816.0    52697.0  ...
# France           55200.0      55100.0  492.0     25.0  3834.0    51747.0  ...
# France           56000.0      55400.0  491.0     25.0  3832.0    51950.0  ...
# France           56000.0      55000.0  492.0     25.0  3839.0    51625.0  ...
#
#            Hydraulique - Fil de l?eau + éclusée  Hydraulique - Lacs  \
# Périmètre
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
#
#            Hydraulique - STEP turbinage  Bioénergies - Déchets  \
# Périmètre
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
#
#            Bioénergies - Biomasse  Bioénergies - Biogaz   Stockage batterie  \
# Périmètre
# France                        NaN                   NaN                 NaN
# France                        NaN                   NaN                 NaN
# France                        NaN                   NaN                 NaN
# France                        NaN                   NaN                 NaN
# France                        NaN                   NaN                 NaN
#
#            Déstockage batterie  Eolien terrestre  Eolien offshore
# Périmètre
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (275277, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275277 entries, France to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Nature                                275264 non-null  object
#  1   Date                                  275262 non-null  object
#  2   Heures                                275262 non-null  object
#  3   Consommation                          256109 non-null  float64
#  4   Prévision J-1                         275262 non-null  float64
#  5   Prévision J                           275167 non-null  float64
#  6   Fioul                                 256109 non-null  float64
#  7   Charbon                               256109 non-null  float64
#  8   Gaz                                   256109 non-null  float64
#  9   Nucléaire                             256109 non-null  float64
#  10  Eolien                                256109 non-null  float64
#  11  Solaire                               256109 non-null  float64
#  12  Hydraulique                           256109 non-null  float64
#  13  Pompage                               256109 non-null  float64
#  14  Bioénergies                           256109 non-null  float64
#  15  Ech. physiques                        256109 non-null  float64
#  16  Taux de Co2                           256109 non-null  float64
#  17  Ech. comm. Angleterre                 274535 non-null  float64
#  18  Ech. comm. Espagne                    275159 non-null  float64
#  19  Ech. comm. Italie                     275149 non-null  float64
#  20  Ech. comm. Suisse                     275159 non-null  float64
#  21  Ech. comm. Allemagne-Belgique         275111 non-null  float64
#  22  Fioul - TAC                           238540 non-null  float64
#  23  Fioul - Cogén.                        238540 non-null  float64
#  24  Fioul - Autres                        238540 non-null  float64
#  25  Gaz - TAC                             238540 non-null  float64
#  26  Gaz - Cogén.                          238540 non-null  float64
#  27  Gaz - CCG                             238540 non-null  float64
#  28  Gaz - Autres                          238540 non-null  float64
#  29  Hydraulique - Fil de l?eau + éclusée  238540 non-null  float64
#  30  Hydraulique - Lacs                    238540 non-null  float64
#  31  Hydraulique - STEP turbinage          238540 non-null  float64
#  32  Bioénergies - Déchets                 238540 non-null  float64
#  33  Bioénergies - Biomasse                238540 non-null  float64
#  34  Bioénergies - Biogaz                  238540 non-null  float64
#  35   Stockage batterie                    98284 non-null   float64
#  36  Déstockage batterie                   98284 non-null   float64
#  37  Eolien terrestre                      98284 non-null   float64
#  38  Eolien offshore                       98284 non-null   float64
# dtypes: float64(36), object(3)
# memory usage: 84.0+ MB

# %%
df.describe(include="all")
# Out:
#                      Nature        Date  Heures   Consommation  Prévision J-1  \
# count                275264      275262  275262  256109.000000  275262.000000
# unique                    4        5247      96            NaN            NaN
# top     Données définitives  2026-04-27   00:00            NaN            NaN
# freq                 210384          95    5247            NaN            NaN
# mean                    NaN         NaN     NaN   52979.073765   52424.900644
# std                     NaN         NaN     NaN   11681.280940   11667.586422
# min                     NaN         NaN     NaN   29124.000000   27500.000000
# 25%                     NaN         NaN     NaN   44204.000000   43600.000000
# 50%                     NaN         NaN     NaN   51237.000000   50700.000000
# 75%                     NaN         NaN     NaN   60716.000000   60100.000000
# max                     NaN         NaN     NaN  102098.000000  101000.000000
#
#           Prévision J          Fioul        Charbon            Gaz  \
# count   275167.000000  256109.000000  256109.000000  256109.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     52359.898353     229.380994     695.836671    3184.235080
# std      11629.336157     264.895119    1037.584674    2454.479371
# min          0.000000       0.000000       0.000000     179.000000
# 25%      43700.000000      81.000000      14.000000     915.000000
# 50%      50600.000000     128.000000      25.000000    2656.000000
# 75%      60000.000000     311.000000    1068.000000    4750.000000
# max     102700.000000    5926.000000    6265.000000   10591.000000
#
#             Nucléaire  ...  Hydraulique - Fil de l?eau + éclusée  \
# count   256109.000000  ...                         238540.000000
# unique            NaN  ...                                   NaN
# top               NaN  ...                                   NaN
# freq              NaN  ...                                   NaN
# mean     42500.393391  ...                           4652.493427
# std       7650.786606  ...                           1511.303455
# min      19164.000000  ...                           1211.000000
# 25%      37951.000000  ...                           3410.000000
# 50%      42076.000000  ...                           4787.000000
# 75%      47438.000000  ...                           5861.000000
# max      61712.000000  ...                           8378.000000
#
#         Hydraulique - Lacs  Hydraulique - STEP turbinage  \
# count        238540.000000                 238540.000000
# unique                 NaN                           NaN
# top                    NaN                           NaN
# freq                   NaN                           NaN
# mean           1842.724901                    693.740983
# std            1132.745805                    802.370649
# min              42.000000                      0.000000
# 25%             986.000000                     27.000000
# 50%            1634.000000                    384.000000
# 75%            2461.000000                   1100.000000
# max            7211.000000                   4708.000000
#
#         Bioénergies - Déchets  Bioénergies - Biomasse  Bioénergies - Biogaz  \
# count           238540.000000           238540.000000         238540.000000
# unique                    NaN                     NaN                   NaN
# top                       NaN                     NaN                   NaN
# freq                      NaN                     NaN                   NaN
# mean               482.766643              302.912560            278.170877
# std                 61.682552               89.346743             63.438998
# min                 42.000000              111.000000            111.000000
# 25%                443.000000              250.000000            221.000000
# 50%                488.000000              300.000000            302.000000
# 75%                527.000000              358.000000            333.000000
# max               2655.000000              661.000000            448.000000
#
#          Stockage batterie  Déstockage batterie  Eolien terrestre  \
# count         98284.000000         98284.000000      98284.000000
# unique                 NaN                  NaN               NaN
# top                    NaN                  NaN               NaN
# freq                   NaN                  NaN               NaN
# mean             -1.550771             1.645588       4178.721155
# std              10.653667             9.665974       4019.976419
# min            -283.000000             0.000000          0.000000
# 25%               0.000000             0.000000       1072.750000
# 50%               0.000000             0.000000       3026.000000
# 75%               0.000000             0.000000       6298.000000
# max              96.000000           265.000000      18470.000000
#
#         Eolien offshore
# count      98284.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean         337.102713
# std          444.348275
# min            0.000000
# 25%            0.000000
# 50%          143.500000
# 75%          486.000000
# max         1874.000000
#
# [11 rows x 39 columns]

# %% [markdown]
# # Vue générale

# %%
# Nombre de  valeurs manquantes
valeurs_manquantes = df.isna().sum()
valeurs_manquantes
# Out:
# Nature                                      13
# Date                                        15
# Heures                                      15
# Consommation                             19168
# Prévision J-1                               15
# Prévision J                                110
# Fioul                                    19168
# Charbon                                  19168
# Gaz                                      19168
# Nucléaire                                19168
# Eolien                                   19168
# Solaire                                  19168
# Hydraulique                              19168
# Pompage                                  19168
# Bioénergies                              19168
# Ech. physiques                           19168
# Taux de Co2                              19168
# Ech. comm. Angleterre                      742
# Ech. comm. Espagne                         118
# Ech. comm. Italie                          128
# Ech. comm. Suisse                          118
# Ech. comm. Allemagne-Belgique              166
# Fioul - TAC                              36737
# Fioul - Cogén.                           36737
# Fioul - Autres                           36737
# Gaz - TAC                                36737
# Gaz - Cogén.                             36737
# Gaz - CCG                                36737
# Gaz - Autres                             36737
# Hydraulique - Fil de l?eau + éclusée     36737
# Hydraulique - Lacs                       36737
# Hydraulique - STEP turbinage             36737
# Bioénergies - Déchets                    36737
# Bioénergies - Biomasse                   36737
# Bioénergies - Biogaz                     36737
#  Stockage batterie                      176993
# Déstockage batterie                     176993
# Eolien terrestre                        176993
# Eolien offshore                         176993
# dtype: int64

# %%
# Pourcentage de valeurs manquantes
valeurs_manquantes_pourcent = (df.isna().sum() / df.shape[0]) * 100
valeurs_manquantes_pourcent
# Out:
# Nature                                   0.004723
# Date                                     0.005449
# Heures                                   0.005449
# Consommation                             6.963168
# Prévision J-1                            0.005449
# Prévision J                              0.039960
# Fioul                                    6.963168
# Charbon                                  6.963168
# Gaz                                      6.963168
# Nucléaire                                6.963168
# Eolien                                   6.963168
# Solaire                                  6.963168
# Hydraulique                              6.963168
# Pompage                                  6.963168
# Bioénergies                              6.963168
# Ech. physiques                           6.963168
# Taux de Co2                              6.963168
# Ech. comm. Angleterre                    0.269547
# Ech. comm. Espagne                       0.042866
# Ech. comm. Italie                        0.046499
# Ech. comm. Suisse                        0.042866
# Ech. comm. Allemagne-Belgique            0.060303
# Fioul - TAC                             13.345467
# Fioul - Cogén.                          13.345467
# Fioul - Autres                          13.345467
# Gaz - TAC                               13.345467
# Gaz - Cogén.                            13.345467
# Gaz - CCG                               13.345467
# Gaz - Autres                            13.345467
# Hydraulique - Fil de l?eau + éclusée    13.345467
# Hydraulique - Lacs                      13.345467
# Hydraulique - STEP turbinage            13.345467
# Bioénergies - Déchets                   13.345467
# Bioénergies - Biomasse                  13.345467
# Bioénergies - Biogaz                    13.345467
#  Stockage batterie                      64.296327
# Déstockage batterie                     64.296327
# Eolien terrestre                        64.296327
# Eolien offshore                         64.296327
# dtype: float64

# %%
valeurs_manquantes_graph = valeurs_manquantes[valeurs_manquantes > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 5))
# Prise en charge si valeurs manquetes à 0
if valeurs_manquantes_graph.empty:
    ax = plt.gca()
    ax.text(0.5, 0.5, "Aucune valeur manquante",
            ha="center", va="center", fontsize=12)
    ax.axis("off")
else:
    valeurs_manquantes_graph.plot(kind="bar")
    plt.title("Valeurs manquantes par colonne")
    plt.ylabel("Nombre de valeurs manquantes")
    plt.xticks(rotation=45, ha="right")

plt.show()

# %%
# Vérification valeurs numériques float uniques
numeric_float = df.select_dtypes('float64')

for col in numeric_float.columns:
  print(f"Colonne {col} : ", numeric_float[col].nunique())
# Out:
# Colonne Consommation :  50101
# Colonne Prévision J-1 :  2049
# Colonne Prévision J :  3396
# Colonne Fioul :  2454
# Colonne Charbon :  5451
# Colonne Gaz :  9581
# Colonne Nucléaire :  36588
# Colonne Eolien :  16548
# Colonne Solaire :  14052
# Colonne Hydraulique :  14222
# Colonne Pompage :  3840
# Colonne Bioénergies :  1016
# Colonne Ech. physiques :  26607
# Colonne Taux de Co2 :  137
# Colonne Ech. comm. Angleterre :  6914
# Colonne Ech. comm. Espagne :  6702
# Colonne Ech. comm. Italie :  5807
# Colonne Ech. comm. Suisse :  5094
# Colonne Ech. comm. Allemagne-Belgique :  16276
# Colonne Fioul - TAC :  1269
# Colonne Fioul - Cogén. :  308
# Colonne Fioul - Autres :  1611
# Colonne Gaz - TAC :  772
# Colonne Gaz - Cogén. :  3225
# Colonne Gaz - CCG :  6430
# Colonne Gaz - Autres :  1736
# Colonne Hydraulique - Fil de l?eau + éclusée :  6826
# Colonne Hydraulique - Lacs :  6247
# Colonne Hydraulique - STEP turbinage :  4168
# Colonne Bioénergies - Déchets :  440
# Colonne Bioénergies - Biomasse :  483
# Colonne Bioénergies - Biogaz :  293
# Colonne  Stockage batterie :  261
# Colonne Déstockage batterie :  165
# Colonne Eolien terrestre :  15167
# Colonne Eolien offshore :  1871

# %%
# Vérification valeurs numériques int uniques
numeric_int = df.select_dtypes('int64')

for col in numeric_int.columns:
  print(f"Colonne {col} : ", numeric_int[col].nunique())

# %%
# Vérification valeurs non numériques float uniques
non_numeric = df.select_dtypes('object')

for col in non_numeric.columns:
  print(f"Colonne {col} : ", non_numeric[col].nunique())
# Out:
# Colonne Nature :  4
# Colonne Date :  5247
# Colonne Heures :  96

# %% [markdown]
# # Cleaning

# %%
df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.shape
# Out:
# (275277, 39)

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275277 entries, France to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   nature                                275264 non-null  object
#  1   date                                  275262 non-null  object
#  2   heures                                275262 non-null  object
#  3   consommation                          256109 non-null  float64
#  4   prévision_j-1                         275262 non-null  float64
#  5   prévision_j                           275167 non-null  float64
#  6   fioul                                 256109 non-null  float64
#  7   charbon                               256109 non-null  float64
#  8   gaz                                   256109 non-null  float64
#  9   nucléaire                             256109 non-null  float64
#  10  eolien                                256109 non-null  float64
#  11  solaire                               256109 non-null  float64
#  12  hydraulique                           256109 non-null  float64
#  13  pompage                               256109 non-null  float64
#  14  bioénergies                           256109 non-null  float64
#  15  ech._physiques                        256109 non-null  float64
#  16  taux_de_co2                           256109 non-null  float64
#  17  ech._comm._angleterre                 274535 non-null  float64
#  18  ech._comm._espagne                    275159 non-null  float64
#  19  ech._comm._italie                     275149 non-null  float64
#  20  ech._comm._suisse                     275159 non-null  float64
#  21  ech._comm._allemagne-belgique         275111 non-null  float64
#  22  fioul_-_tac                           238540 non-null  float64
#  23  fioul_-_cogén.                        238540 non-null  float64
#  24  fioul_-_autres                        238540 non-null  float64
#  25  gaz_-_tac                             238540 non-null  float64
#  26  gaz_-_cogén.                          238540 non-null  float64
#  27  gaz_-_ccg                             238540 non-null  float64
#  28  gaz_-_autres                          238540 non-null  float64
#  29  hydraulique_-_fil_de_l?eau_+_éclusée  238540 non-null  float64
#  30  hydraulique_-_lacs                    238540 non-null  float64
#  31  hydraulique_-_step_turbinage          238540 non-null  float64
#  32  bioénergies_-_déchets                 238540 non-null  float64
#  33  bioénergies_-_biomasse                238540 non-null  float64
#  34  bioénergies_-_biogaz                  238540 non-null  float64
#  35  stockage_batterie                     98284 non-null   float64
#  36  déstockage_batterie                   98284 non-null   float64
#  37  eolien_terrestre                      98284 non-null   float64
#  38  eolien_offshore                       98284 non-null   float64
# dtypes: float64(36), object(3)
# memory usage: 84.0+ MB
# None
#         consommation  prévision_j-1    prévision_j          fioul  \
# count  256109.000000  275262.000000  275167.000000  256109.000000
# mean    52979.073765   52424.900644   52359.898353     229.380994
# std     11681.280940   11667.586422   11629.336157     264.895119
# min     29124.000000   27500.000000       0.000000       0.000000
# 25%     44204.000000   43600.000000   43700.000000      81.000000
# 50%     51237.000000   50700.000000   50600.000000     128.000000
# 75%     60716.000000   60100.000000   60000.000000     311.000000
# max    102098.000000  101000.000000  102700.000000    5926.000000
#
#              charbon            gaz      nucléaire         eolien  \
# count  256109.000000  256109.000000  256109.000000  256109.000000
# mean      695.836671    3184.235080   42500.393391    3704.785658
# std      1037.584674    2454.479371    7650.786606    3332.943063
# min         0.000000     179.000000   19164.000000      21.000000
# 25%        14.000000     915.000000   37951.000000    1342.000000
# 50%        25.000000    2656.000000   42076.000000    2584.000000
# 75%      1068.000000    4750.000000   47438.000000    4970.000000
# max      6265.000000   10591.000000   61712.000000   20131.000000
#
#              solaire    hydraulique  ...  \
# count  256109.000000  256109.000000  ...
# mean     1587.866674    7190.639888  ...
# std      2814.755726    2824.862381  ...
# min         0.000000    1387.000000  ...
# 25%         0.000000    5047.000000  ...
# 50%        23.000000    6946.000000  ...
# 75%      2106.000000    9040.000000  ...
# max     21627.000000   17947.000000  ...
#
#        hydraulique_-_fil_de_l?eau_+_éclusée  hydraulique_-_lacs  \
# count                         238540.000000       238540.000000
# mean                            4652.493427         1842.724901
# std                             1511.303455         1132.745805
# min                             1211.000000           42.000000
# 25%                             3410.000000          986.000000
# 50%                             4787.000000         1634.000000
# 75%                             5861.000000         2461.000000
# max                             8378.000000         7211.000000
#
#        hydraulique_-_step_turbinage  bioénergies_-_déchets  \
# count                 238540.000000          238540.000000
# mean                     693.740983             482.766643
# std                      802.370649              61.682552
# min                        0.000000              42.000000
# 25%                       27.000000             443.000000
# 50%                      384.000000             488.000000
# 75%                     1100.000000             527.000000
# max                     4708.000000            2655.000000
#
#        bioénergies_-_biomasse  bioénergies_-_biogaz  stockage_batterie  \
# count           238540.000000         238540.000000       98284.000000
# mean               302.912560            278.170877          -1.550771
# std                 89.346743             63.438998          10.653667
# min                111.000000            111.000000        -283.000000
# 25%                250.000000            221.000000           0.000000
# 50%                300.000000            302.000000           0.000000
# 75%                358.000000            333.000000           0.000000
# max                661.000000            448.000000          96.000000
#
#        déstockage_batterie  eolien_terrestre  eolien_offshore
# count         98284.000000      98284.000000     98284.000000
# mean              1.645588       4178.721155       337.102713
# std               9.665974       4019.976419       444.348275
# min               0.000000          0.000000         0.000000
# 25%               0.000000       1072.750000         0.000000
# 50%               0.000000       3026.000000       143.500000
# 75%               0.000000       6298.000000       486.000000
# max             265.000000      18470.000000      1874.000000
#
# [8 rows x 36 columns]

# %%
df.head()
# Out:
#                         nature        date heures  consommation  \
# Périmètre
# France     Données définitives  2012-01-01  00:00       58315.0
# France     Données définitives  2012-01-01  00:30       58315.0
# France     Données définitives  2012-01-01  01:00       56231.0
# France     Données définitives  2012-01-01  01:30       56075.0
# France     Données définitives  2012-01-01  02:00       55532.0
#
#            prévision_j-1  prévision_j  fioul  charbon     gaz  nucléaire  ...  \
# Périmètre                                                                 ...
# France           58200.0      58200.0  492.0     25.0  3816.0    52697.0  ...
# France           57200.0      56900.0  492.0     25.0  3816.0    52697.0  ...
# France           55200.0      55100.0  492.0     25.0  3834.0    51747.0  ...
# France           56000.0      55400.0  491.0     25.0  3832.0    51950.0  ...
# France           56000.0      55000.0  492.0     25.0  3839.0    51625.0  ...
#
#            hydraulique_-_fil_de_l?eau_+_éclusée  hydraulique_-_lacs  \
# Périmètre
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
# France                                      NaN                 NaN
#
#            hydraulique_-_step_turbinage  bioénergies_-_déchets  \
# Périmètre
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
# France                              NaN                    NaN
#
#            bioénergies_-_biomasse  bioénergies_-_biogaz  stockage_batterie  \
# Périmètre
# France                        NaN                   NaN                NaN
# France                        NaN                   NaN                NaN
# France                        NaN                   NaN                NaN
# France                        NaN                   NaN                NaN
# France                        NaN                   NaN                NaN
#
#            déstockage_batterie  eolien_terrestre  eolien_offshore
# Périmètre
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
# France                     NaN               NaN              NaN
#
# [5 rows x 39 columns]

# %%
# Écriture directe du DataFrame cleaned sur S3
df.to_csv(
    "s3://renergies99-lead-bucket/public/prod/eCO2mix_RTE_Annuel-Definitif_cleaned.csv",
    index=False,
    storage_options={
        "key": API_KEY_S3,
        "secret": API_SECRET_KEY_S3,
    },
)
